# %%
from sql_queries import (DROP_TABLE_QUERIES, CREATE_TABLE_QUERIES,
                         COPY_TABLE_QUERIES, INSERT_TABLE_QUERIES)

# %%
for drop, create, insert in zip(DROP_TABLE_QUERIES, CREATE_TABLE_QUERIES,
                                COPY_TABLE_QUERIES + INSERT_TABLE_QUERIES):
    print()
    print(drop)
    print()
    print(create)
    print()
    print(insert)
    print()
    print(80 * '=')
# Out:
# DROP TABLE IF EXISTS staging_events CASCADE;
#
# CREATE TABLE IF NOT EXISTS staging_events (
#   artist VARCHAR,
#   auth VARCHAR,
#   firstName VARCHAR,
#   gender CHAR(1),
#   itemInSession SMALLINT,
#   lastName VARCHAR,
#   length DOUBLE PRECISION,
#   level CHAR(4),
#   location VARCHAR,
#   method VARCHAR(6),
#   page VARCHAR,
#   registration INT8,
#   sessionId INT4,
#   song VARCHAR,
#   status INT2,
#   ts INT8,
#   userAgent VARCHAR,
#   userId INT4);
#
# COPY staging_events
# FROM 's3://udacity-dend/log_data'
# IAM_ROLE '<some-value-here>'
# REGION 'us-west-2'
# FORMAT JSON AS 's3://udacity-dend/log_json_path.json'
# EMPTYASNULL
# BLANKSASNULL;
#
# ...
#
# DROP TABLE IF EXISTS staging_songs CASCADE;
#
# CREATE TABLE IF NOT EXISTS staging_songs (
#   num_songs INT2,
#   artist_id VARCHAR(64),
#   artist_latitude DOUBLE PRECISION,
#   artist_longitude DOUBLE PRECISION,
#   artist_location VARCHAR,
#   artist_name VARCHAR,
#   song_id VARCHAR(64),
#   title VARCHAR,
# ...
